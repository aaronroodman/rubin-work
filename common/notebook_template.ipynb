# %% [markdown]
# # Title Here (v1)
#
# **Author:** Your Name
# **Date Created:** YYYY-MM-DD
# **Last Modified:** YYYY-MM-DD
# **Status:** Draft | In Progress | Complete
# **Keywords:** keyword1, keyword2, keyword3
#
# ## Description
#
# Brief description of what this notebook does.
#
# Key functionality:
# 1. First thing this notebook does
# 2. Second thing this notebook does
# 3. Third thing this notebook does
#
# **Output:** What this notebook produces (plots, tables, files, etc.)
#
# **Based on:** Reference to any prior work, tickets, or documents

# %% [markdown]
# ## Change Log
#
# | Date | Author | Description |
# |------|--------|-------------|
# | YYYY-MM-DD | Your Name | Initial version |

# %% [markdown]
# ## Table of Contents
#
# 1. [Parameters](#params)
# 2. [Setup & Imports](#setup)
# 3. [Helper Functions](#functions)
# 4. [Data Access](#data)
# 5. [Analysis](#analysis)
# 6. [Results & Plots](#results)

# %% [markdown]
# <a id='params'></a>
# ## Parameters

# %%
# ============================================================
# Parameters — All configurable values collected here
# ============================================================

# day_obs = 20250101              # Observation date
# butler_repo = '/repo/main'      # Butler repository path
# collections = ['LSSTComCam/raw/all']  # Butler collections
# output_file = None              # Output file path (None = no file output)

# %% [markdown]
# <a id='setup'></a>
# ## Setup & Imports

# %%
import os
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# from astropy import units as u
# from astropy.coordinates import SkyCoord
# import astropy.io.fits as fits

# LSST imports (available on RSP)
# import lsst.daf.butler as dafButler
# import lsst.afw.display as afwDisplay

# from tqdm.notebook import tqdm

# Add repo root to path for common imports
sys.path.insert(0, str(Path.cwd().parent))
from common.utils import setup_plotting

setup_plotting()

# %% [markdown]
# <a id='functions'></a>
# ## Helper Functions

# %%
def example_function(x, y):
    """Short description of the function.

    Parameters
    ----------
    x : float
        Description of x.
    y : float
        Description of y.

    Returns
    -------
    float
        Description of return value.
    """
    return x + y

# %% [markdown]
# <a id='data'></a>
# ## Data Access

# %%
# Data access code here
# butler = dafButler.Butler(butler_repo, collections=collections)

# %% [markdown]
# <a id='analysis'></a>
# ## Analysis

# %%
# Analysis code here

# %% [markdown]
# <a id='results'></a>
# ## Results & Plots

# %%
# Results and plotting code here
